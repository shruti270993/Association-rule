# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules
from mlxtend.preprocessing import TransactionEncoder
# conda install -c conda-forge mlxtend

# %%
my_movies=pd.read_csv("C:\\Users\\usr\\Downloads\\my_movies.csv")

# %%
df=pd.get_dummies(my_movies)
df.head()
df.describe()
# Out:
#        Sixth Sense  Gladiator      LOTR1  Harry Potter1    Patriot      LOTR2  \
# count    10.000000  10.000000  10.000000      10.000000  10.000000  10.000000
# mean      0.600000   0.700000   0.200000       0.200000   0.600000   0.200000
# std       0.516398   0.483046   0.421637       0.421637   0.516398   0.421637
# min       0.000000   0.000000   0.000000       0.000000   0.000000   0.000000
# 25%       0.000000   0.250000   0.000000       0.000000   0.000000   0.000000
# 50%       1.000000   1.000000   0.000000       0.000000   1.000000   0.000000
# 75%       1.000000   1.000000   0.000000       0.000000   1.000000   0.000000
# max       1.000000   1.000000   1.000000       1.000000   1.000000   1.000000
#
#        Harry Potter2       LOTR  Braveheart  Green Mile  ...    V2_LOTR  \
# count      10.000000  10.000000   10.000000   10.000000  ...  10.000000
# mean        0.100000   0.100000    0.100000    0.200000  ...   0.100000
# std         0.316228   0.316228    0.316228    0.421637  ...   0.316228
# min         0.000000   0.000000    0.000000    0.000000  ...   0.000000
# 25%         0.000000   0.000000    0.000000    0.000000  ...   0.000000
# 50%         0.000000   0.000000    0.000000    0.000000  ...   0.000000
# 75%         0.000000   0.000000    0.000000    0.000000  ...   0.000000
# max         1.000000   1.000000    1.000000    1.000000  ...   1.000000
#
#         V2_LOTR1   V2_LOTR2  V2_Patriot  V3_Braveheart  V3_Gladiator  \
# count  10.000000  10.000000   10.000000      10.000000     10.000000
# mean    0.100000   0.100000    0.600000       0.100000      0.100000
# std     0.316228   0.316228    0.516398       0.316228      0.316228
# min     0.000000   0.000000    0.000000       0.000000      0.000000
# 25%     0.000000   0.000000    0.000000       0.000000      0.000000
# 50%     0.000000   0.000000    1.000000       0.000000      0.000000
# 75%     0.000000   0.000000    1.000000       0.000000      0.000000
# max     1.000000   1.000000    1.000000       1.000000      1.000000
#
#        V3_Harry Potter1  V3_Sixth Sense  V4_Green Mile   V5_LOTR2
# count         10.000000       10.000000      10.000000  10.000000
# mean           0.100000        0.400000       0.200000   0.100000
# std            0.316228        0.516398       0.421637   0.316228
# min            0.000000        0.000000       0.000000   0.000000
# 25%            0.000000        0.000000       0.000000   0.000000
# 50%            0.000000        0.000000       0.000000   0.000000
# 75%            0.000000        1.000000       0.000000   0.000000
# max            1.000000        1.000000       1.000000   1.000000
#
# [8 rows x 25 columns]

# %%
frequent_itemsets = apriori(df, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
#       support                                           itemsets
# 0         0.6                                      (Sixth Sense)
# 1         0.7                                        (Gladiator)
# 2         0.2                                            (LOTR1)
# 3         0.2                                    (Harry Potter1)
# 4         0.6                                          (Patriot)
# ...       ...                                                ...
# 1392      0.1  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 1393      0.1  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 1394      0.1  (Green Mile, V1_Sixth Sense, V2_LOTR1, V4_Gree...
# 1395      0.1  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 1396      0.1  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
#
# [1397 rows x 2 columns]

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0.6)
rules
# Out:
#               antecedents                                        consequents  \
# 0             (Gladiator)                                      (Sixth Sense)
# 1           (Sixth Sense)                                        (Gladiator)
# 2                 (LOTR1)                                      (Sixth Sense)
# 3           (Sixth Sense)                                            (LOTR1)
# 4         (Harry Potter1)                                      (Sixth Sense)
# ...                   ...                                                ...
# 64247             (LOTR2)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64248          (V5_LOTR2)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64249     (Harry Potter1)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64250  (V3_Harry Potter1)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64251       (Sixth Sense)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
#
#        antecedent support  consequent support  support  confidence       lift  \
# 0                     0.7                 0.6      0.5    0.714286   1.190476
# 1                     0.6                 0.7      0.5    0.833333   1.190476
# 2                     0.2                 0.6      0.1    0.500000   0.833333
# 3                     0.6                 0.2      0.1    0.166667   0.833333
# 4                     0.2                 0.6      0.1    0.500000   0.833333
# ...                   ...                 ...      ...         ...        ...
# 64247                 0.2                 0.1      0.1    0.500000   5.000000
# 64248                 0.1                 0.1      0.1    1.000000  10.000000
# 64249                 0.2                 0.1      0.1    0.500000   5.000000
# 64250                 0.1                 0.1      0.1    1.000000  10.000000
# 64251                 0.6                 0.1      0.1    0.166667   1.666667
#
#        leverage  conviction
# 0          0.08        1.40
# 1          0.08        1.80
# 2         -0.02        0.80
# 3         -0.02        0.96
# 4         -0.02        0.80
# ...         ...         ...
# 64247      0.08        1.80
# 64248      0.09         inf
# 64249      0.08        1.80
# 64250      0.09         inf
# 64251      0.04        1.08
#
# [64252 rows x 9 columns]

# %%
rules.sort_values('lift',ascending = False)
# Out:
#                                              antecedents  \
# 32126  (Green Mile, Harry Potter1, V3_Harry Potter1, ...
# 40481       (V1_Sixth Sense, V3_Harry Potter1, V5_LOTR2)
# 40448  (V1_Sixth Sense, V4_Green Mile, V5_LOTR2, Sixt...
# 40449  (V1_Sixth Sense, Harry Potter1, V4_Green Mile,...
# 40450  (V1_Sixth Sense, Harry Potter1, V4_Green Mile,...
# ...                                                  ...
# 682                          (Green Mile, V4_Green Mile)
# 218                                          (Gladiator)
# 669                                          (Gladiator)
# 664                         (Green Mile, V1_Sixth Sense)
# 56                                       (V4_Green Mile)
#
#                                              consequents  antecedent support  \
# 32126                        (LOTR2, LOTR1, Sixth Sense)                 0.1
# 40481  (Green Mile, V4_Green Mile, Harry Potter1, Six...                 0.1
# 40448      (Green Mile, Harry Potter1, V3_Harry Potter1)                 0.1
# 40449                (Green Mile, V5_LOTR2, Sixth Sense)                 0.1
# 40450           (Green Mile, V3_Harry Potter1, V5_LOTR2)                 0.1
# ...                                                  ...                 ...
# 682                                          (Gladiator)                 0.2
# 218                            (Green Mile, Sixth Sense)                 0.7
# 669                         (Green Mile, V1_Sixth Sense)                 0.7
# 664                                          (Gladiator)                 0.2
# 56                                           (Gladiator)                 0.2
#
#        consequent support  support  confidence       lift  leverage  \
# 32126                 0.1      0.1    1.000000  10.000000      0.09
# 40481                 0.1      0.1    1.000000  10.000000      0.09
# 40448                 0.1      0.1    1.000000  10.000000      0.09
# 40449                 0.1      0.1    1.000000  10.000000      0.09
# 40450                 0.1      0.1    1.000000  10.000000      0.09
# ...                   ...      ...         ...        ...       ...
# 682                   0.7      0.1    0.500000   0.714286     -0.04
# 218                   0.2      0.1    0.142857   0.714286     -0.04
# 669                   0.2      0.1    0.142857   0.714286     -0.04
# 664                   0.7      0.1    0.500000   0.714286     -0.04
# 56                    0.7      0.1    0.500000   0.714286     -0.04
#
#        conviction
# 32126         inf
# 40481         inf
# 40448         inf
# 40449         inf
# 40450         inf
# ...           ...
# 682      0.600000
# 218      0.933333
# 669      0.933333
# 664      0.600000
# 56       0.600000
#
# [64252 rows x 9 columns]

# %%
rules[rules.lift>1]
# Out:
#               antecedents                                        consequents  \
# 0             (Gladiator)                                      (Sixth Sense)
# 1           (Sixth Sense)                                        (Gladiator)
# 6               (Patriot)                                      (Sixth Sense)
# 7           (Sixth Sense)                                          (Patriot)
# 10                 (LOTR)                                      (Sixth Sense)
# ...                   ...                                                ...
# 64247             (LOTR2)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64248          (V5_LOTR2)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64249     (Harry Potter1)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64250  (V3_Harry Potter1)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
# 64251       (Sixth Sense)  (Green Mile, V1_Sixth Sense, LOTR1, V2_LOTR1, ...
#
#        antecedent support  consequent support  support  confidence       lift  \
# 0                     0.7                 0.6      0.5    0.714286   1.190476
# 1                     0.6                 0.7      0.5    0.833333   1.190476
# 6                     0.6                 0.6      0.4    0.666667   1.111111
# 7                     0.6                 0.6      0.4    0.666667   1.111111
# 10                    0.1                 0.6      0.1    1.000000   1.666667
# ...                   ...                 ...      ...         ...        ...
# 64247                 0.2                 0.1      0.1    0.500000   5.000000
# 64248                 0.1                 0.1      0.1    1.000000  10.000000
# 64249                 0.2                 0.1      0.1    0.500000   5.000000
# 64250                 0.1                 0.1      0.1    1.000000  10.000000
# 64251                 0.6                 0.1      0.1    0.166667   1.666667
#
#        leverage  conviction
# 0          0.08        1.40
# 1          0.08        1.80
# 6          0.04        1.20
# 7          0.04        1.20
# 10         0.04         inf
# ...         ...         ...
# 64247      0.08        1.80
# 64248      0.09         inf
# 64249      0.08        1.80
# 64250      0.09         inf
# 64251      0.04        1.08
#
# [64202 rows x 9 columns]
